# %%
import pandas as pd

# %%
from google.colab import drive

# Mount your Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
dataset=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Regression/Assignment/insurance_pre.csv")

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[['age', 'bmi', 'children', 'charges', 'sex_male']]

# %%
independent
# Out:
#       age     bmi  children      charges  sex_male
# 0      19  27.900         0  16884.92400         0
# 1      18  33.770         1   1725.55230         1
# 2      28  33.000         3   4449.46200         1
# 3      33  22.705         0  21984.47061         1
# 4      32  28.880         0   3866.85520         1
# ...   ...     ...       ...          ...       ...
# 1333   50  30.970         3  10600.54830         1
# 1334   18  31.920         0   2205.98080         0
# 1335   18  36.850         0   1629.83350         0
# 1336   21  25.800         0   2007.94500         0
# 1337   61  29.070         0  29141.36030         0
#
# [1338 rows x 5 columns]

# %%
dependent=dataset[["smoker_yes"]]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(independent, dependent, test_size=0.30,random_state=0)

# %%
from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators = 8000, random_state = 50)
regressor.fit(X_train, y_train)
# Out:
# <ipython-input-47-dc5b2dafebe9>:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   regressor.fit(X_train, y_train)
# RandomForestRegressor(n_estimators=8000, random_state=50)

# %%
y_pred=regressor.predict(X_test)

# %%
from sklearn.metrics import r2_score
r_score=r2_score(y_test,y_pred)

# %%
r_score
# Out:
# 0.8293803028589679

# %%
import pickle
filename="/content/drive/MyDrive/Colab Notebooks/Machine Learning-Regression/1.Traditional Way/5.Random Forest/finalized_model_Forest1.sav"
pickle.dump(regressor,open(filename,'wb'))

# %%
loaded_model=pickle.load(open("/content/drive/MyDrive/Colab Notebooks/Machine Learning-Regression/1.Traditional Way/5.Random Forest/finalized_model_Forest.sav",'rb'))
result=loaded_model.predict([[1234,345,4565,1,0]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:318: UserWarning: Trying to unpickle estimator DecisionTreeRegressor from version 1.0 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:318: UserWarning: Trying to unpickle estimator RandomForestRegressor from version 1.0 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(

# %%
result
# Out:
# array([47938.381])
